# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1- Loading Data

# %%
path = "../data/pre_prpocessed_dataset.csv"
data = pd.read_csv(path)

# %%
data.head()
# Out:
#    Unnamed: 0 account_open_date  age     location occupation  income_level  \
# 0           0        2023-11-09   56  Los Angeles    Teacher         40099
# 1           1        2022-09-11   69     New York   Engineer          2050
# 2           2        2020-07-12   46        Miami   Engineer         71936
# 3           5        2022-03-06   25      Chicago    Teacher         59349
# 4           6        2023-10-26   38  Los Angeles     Banker          6925
#
#    fico_score  delinquency_status  charge_off_status  \
# 0       424.0                 108                  1
# 1       483.0                   0                  0
# 2       566.0                   0                  0
# 3       688.0                   0                  0
# 4       740.0                   0                  0
#
#    number_of_credit_applications  ...  number_of_delinquent_accounts  \
# 0                             10  ...                            4.0
# 1                              1  ...                            3.0
# 2                              1  ...                            2.0
# 3                              1  ...                            0.0
# 4                              1  ...                            0.0
#
#    number_of_defaulted_accounts  earliest_credit_account  \
# 0                             2               2018-09-11
# 1                             2               2023-03-08
# 2                             0               2024-04-26
# 3                             0               2018-11-18
# 4                             0               2022-03-01
#
#    recent_trade_activity  new_accounts_opened_last_12months  \
# 0             2024-03-07                                  3
# 1             2024-01-28                                  3
# 2             2024-10-03                                  2
# 3             2024-03-19                                  0
# 4             2024-01-04                                  0
#
#    multiple_applications_short_time_period unusual_submission_pattern  \
# 0                                        1                          1
# 1                                        0                          1
# 2                                        0                          0
# 3                                        0                          0
# 4                                        0                          0
#
#   applications_submitted_during_odd_hours  watchlist_blacklist_flag  \
# 0                                       0                         0
# 1                                       0                         0
# 2                                       0                         0
# 3                                       1                         0
# 4                                       1                         0
#
#    public_records_flag
# 0                    1
# 1                    0
# 2                    0
# 3                    0
# 4                    0
#
# [5 rows x 24 columns]

# %%
data.describe()
# Out:
#         Unnamed: 0          age  income_level   fico_score  \
# count  6748.000000  6748.000000   6748.000000  6748.000000
# mean   3488.881743    46.148488  23717.458062   616.211618
# std    2019.047398    16.411338  21872.292686   130.181643
# min       0.000000    18.000000   2000.000000   301.000000
# 25%    1742.750000    32.000000   6921.750000   521.000000
# 50%    3477.500000    46.000000  14976.000000   635.500000
# 75%    5241.250000    61.000000  38267.500000   722.000000
# max    6999.000000    74.000000  99957.000000   848.000000
#
#        delinquency_status  charge_off_status  number_of_credit_applications  \
# count         6748.000000        6748.000000                    6748.000000
# mean            25.252964           0.260670                       1.811648
# std             42.736714           0.439033                       1.934514
# min              0.000000           0.000000                       1.000000
# 25%              0.000000           0.000000                       1.000000
# 50%              0.000000           0.000000                       1.000000
# 75%             29.000000           1.000000                       1.000000
# max            119.000000           1.000000                      10.000000
#
#        debt_to_income_ratio  payment_methods_high_risk    max_balance  \
# count           6748.000000                6748.000000    6748.000000
# mean               1.477336                   0.237404   50462.244115
# std                0.684346                   0.425523   50151.749003
# min                0.438413                   0.000000     930.516529
# 25%                1.052407                   0.000000   25530.592888
# 50%                1.320511                   0.000000   44815.552299
# 75%                1.719710                   0.000000   70145.742751
# max                9.975930                   1.000000  999922.083300
#
#        avg_balance_last_12months  number_of_delinquent_accounts  \
# count                6748.000000                    6748.000000
# mean                33472.154979                       1.210581
# std                 21801.235282                       1.565324
# min                   457.869809                       0.000000
# 25%                 14274.514672                       0.000000
# 50%                 30352.353060                       0.000000
# 75%                 50725.277651                       3.000000
# max                 92117.793445                       4.000000
#
#        number_of_defaulted_accounts  new_accounts_opened_last_12months  \
# count                   6748.000000                        6748.000000
# mean                       0.499555                           1.383669
# std                        0.730357                           1.594867
# min                        0.000000                           0.000000
# 25%                        0.000000                           0.000000
# 50%                        0.000000                           0.000000
# 75%                        1.000000                           3.000000
# max                        2.000000                           4.000000
#
#        multiple_applications_short_time_period  unusual_submission_pattern  \
# count                              6748.000000                 6748.000000
# mean                                  0.258447                    0.191168
# std                                   0.437813                    0.393250
# min                                   0.000000                    0.000000
# 25%                                   0.000000                    0.000000
# 50%                                   0.000000                    0.000000
# 75%                                   1.000000                    0.000000
# max                                   1.000000                    1.000000
#
#        applications_submitted_during_odd_hours  watchlist_blacklist_flag  \
# count                              6748.000000               6748.000000
# mean                                  0.314908                  0.126260
# std                                   0.464514                  0.332166
# min                                   0.000000                  0.000000
# 25%                                   0.000000                  0.000000
# 50%                                   0.000000                  0.000000
# 75%                                   1.000000                  0.000000
# max                                   1.000000                  1.000000
#
#        public_records_flag
# count          6748.000000
# mean              0.201986
# std               0.401511
# min               0.000000
# 25%               0.000000
# 50%               0.000000
# 75%               0.000000
# max               1.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6748 entries, 0 to 6747
# Data columns (total 24 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Unnamed: 0                               6748 non-null   int64
#  1   account_open_date                        6748 non-null   object
#  2   age                                      6748 non-null   int64
#  3   location                                 6748 non-null   object
#  4   occupation                               6748 non-null   object
#  5   income_level                             6748 non-null   int64
#  6   fico_score                               6748 non-null   float64
#  7   delinquency_status                       6748 non-null   int64
#  8   charge_off_status                        6748 non-null   int64
#  9   number_of_credit_applications            6748 non-null   int64
#  10  debt_to_income_ratio                     6748 non-null   float64
#  11  payment_methods_high_risk                6748 non-null   int64
#  12  max_balance                              6748 non-null   float64
#  13  avg_balance_last_12months                6748 non-null   float64
#  14  number_of_delinquent_accounts            6748 non-null   float64
#  15  number_of_defaulted_accounts             6748 non-null   int64
#  16  earliest_credit_account                  6748 non-null   object
#  17  recent_trade_activity                    6748 non-null   object
#  18  new_accounts_opened_last_12months        6748 non-null   int64
#  19  multiple_applications_short_time_period  6748 non-null   int64
#  20  unusual_submission_pattern               6748 non-null   int64
#  21  applications_submitted_during_odd_hours  6748 non-null   int64
#  22  watchlist_blacklist_flag                 6748 non-null   int64
#  23  public_records_flag                      6748 non-null   int64
# dtypes: float64(5), int64(14), object(5)
# memory usage: 1.2+ MB

# %% [markdown]
# ## 2 - Univariate Analysis

# %% [markdown]
# ### 2.1 `Age`

# %%
col = "age"
mean_value = data[col].mean()
median_value = data[col].median()

fig, axes = plt.subplots(1, 2, figsize=(16, 6))

sns.histplot(data[col], kde=True, bins=10, ax=axes[0])
axes[0].axvline(mean_value, color='r', linestyle='--', label=f'Mean: {mean_value:.2f}')
axes[0].axvline(median_value, color='g', linestyle='-', label=f'Median: {median_value:.2f}')
axes[0].set_title(f"Distribution of {col}")
axes[0].legend()

sns.boxplot(data[col], ax=axes[1])
axes[1].set_title(f"Boxplot of {col}")

plt.tight_layout()
plt.show()
# Out:
# C:\Users\hcham\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ### 2.2 `Income_Level`

# %%
col = "income_level"
mean_value = data[col].mean()
median_value = data[col].median()

fig, axes = plt.subplots(1, 2, figsize=(16, 6))

sns.histplot(data[col], kde=True, bins=10, ax=axes[0])
axes[0].axvline(mean_value, color='r', linestyle='--', label=f'Mean: {mean_value:.2f}')
axes[0].axvline(median_value, color='g', linestyle='-', label=f'Median: {median_value:.2f}')
axes[0].set_title(f"Distribution of {col}")
axes[0].legend()

sns.boxplot(data[col], ax=axes[1])
axes[1].set_title(f"Boxplot of {col}")

plt.tight_layout()
plt.show()
# Out:
# C:\Users\hcham\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ### 2.3 `Fico_score`

# %%
col = "fico_score"
mean_value = data[col].mean()
median_value = data[col].median()

fig, axes = plt.subplots(1, 2, figsize=(16, 6))

sns.histplot(data[col], kde=True, bins=10, ax=axes[0])
axes[0].axvline(mean_value, color='r', linestyle='--', label=f'Mean: {mean_value:.2f}')
axes[0].axvline(median_value, color='g', linestyle='-', label=f'Median: {median_value:.2f}')
axes[0].set_title(f"Distribution of {col}")
axes[0].legend()

sns.boxplot(data[col], ax=axes[1])
axes[1].set_title(f"Boxplot of {col}")

plt.tight_layout()
plt.show()
# Out:
# C:\Users\hcham\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ### 2.4 `delinquency_status`

# %%
col = "delinquency_status"
mean_value = data[col].mean()
median_value = data[col].median()

fig, axes = plt.subplots(1, 2, figsize=(16, 6))

sns.histplot(data[col], kde=True, bins=10, ax=axes[0])
axes[0].axvline(mean_value, color='r', linestyle='--', label=f'Mean: {mean_value:.2f}')
axes[0].axvline(median_value, color='g', linestyle='-', label=f'Median: {median_value:.2f}')
axes[0].set_title(f"Distribution of {col}")
axes[0].legend()

sns.boxplot(data[col], ax=axes[1])
axes[1].set_title(f"Boxplot of {col}")

plt.tight_layout()
plt.show()
# Out:
# C:\Users\hcham\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ### 2.5 `number_of_credit_applications`

# %%
col = "number_of_credit_applications"
mean_value = data[col].mean()
median_value = data[col].median()

fig, axes = plt.subplots(1, 2, figsize=(16, 6))

sns.histplot(data[col], kde=True, bins=10, ax=axes[0])
axes[0].axvline(mean_value, color='r', linestyle='--', label=f'Mean: {mean_value:.2f}')
axes[0].axvline(median_value, color='g', linestyle='-', label=f'Median: {median_value:.2f}')
axes[0].set_title(f"Distribution of {col}")
axes[0].legend()

sns.boxplot(data[col], ax=axes[1])
axes[1].set_title(f"Boxplot of {col}")

plt.tight_layout()
plt.show()
# Out:
# C:\Users\hcham\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ### 2.6 `Debt_to_income_ratio`

# %%
col = "debt_to_income_ratio"
mean_value = data[col].mean()
median_value = data[col].median()

fig, axes = plt.subplots(1, 2, figsize=(16, 6))

sns.histplot(data[col], kde=True, bins=10, ax=axes[0])
axes[0].axvline(mean_value, color='r', linestyle='--', label=f'Mean: {mean_value:.2f}')
axes[0].axvline(median_value, color='g', linestyle='-', label=f'Median: {median_value:.2f}')
axes[0].set_title(f"Distribution of {col}")
axes[0].legend()

sns.boxplot(data[col], ax=axes[1])
axes[1].set_title(f"Boxplot of {col}")

plt.tight_layout()
plt.show()
# Out:
# C:\Users\hcham\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ### 2.7 `Max_balance`

# %%
col = "max_balance"
mean_value = data[col].mean()
median_value = data[col].median()

fig, axes = plt.subplots(1, 2, figsize=(16, 6))

sns.histplot(data[col], kde=True, bins=10, ax=axes[0])
axes[0].axvline(mean_value, color='r', linestyle='--', label=f'Mean: {mean_value:.2f}')
axes[0].axvline(median_value, color='g', linestyle='-', label=f'Median: {median_value:.2f}')
axes[0].set_title(f"Distribution of {col}")
axes[0].legend()

sns.boxplot(data[col], ax=axes[1])
axes[1].set_title(f"Boxplot of {col}")

plt.tight_layout()
plt.show()
# Out:
# C:\Users\hcham\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ### 2.8 `Avg_balance_last_12months`

# %%
col = "avg_balance_last_12months"
mean_value = data[col].mean()
median_value = data[col].median()

fig, axes = plt.subplots(1, 2, figsize=(16, 6))

sns.histplot(data[col], kde=True, bins=10, ax=axes[0])
axes[0].axvline(mean_value, color='r', linestyle='--', label=f'Mean: {mean_value:.2f}')
axes[0].axvline(median_value, color='g', linestyle='-', label=f'Median: {median_value:.2f}')
axes[0].set_title(f"Distribution of {col}")
axes[0].legend()

sns.boxplot(data[col], ax=axes[1])
axes[1].set_title(f"Boxplot of {col}")

plt.tight_layout()
plt.show()
# Out:
# C:\Users\hcham\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ### 2.9 `Number_of_delinquent_accounts`

# %%
col = "number_of_delinquent_accounts"

plt.figure(figsize=(6, 4))
sns.countplot(x=col, data=data)
plt.title('Distribution of number_of_delinquent_accounts')
plt.xlabel('Number of Delinquent Accounts')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ### 2.10 `Number_of_defaulted_accounts`

# %%
col = "number_of_defaulted_accounts"

plt.figure(figsize=(6, 4))
sns.countplot(x=col, data=data)
plt.title('Distribution of number_of_defaulted_accounts')
plt.xlabel('Number_of_defaulted_accounts')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ### 2.11 `New_accounts_opened_last_12months`

# %%
col = "new_accounts_opened_last_12months"

plt.figure(figsize=(6, 4))
sns.countplot(x=col, data=data)
plt.title('Distribution of new_accounts_opened_last_12months')
plt.xlabel('New_accounts_opened_last_12months')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ### 2.12 `Location`

# %%
col= "location"
plt.figure(figsize=(6, 4))
sns.countplot(x=col, data=data)
plt.title(f"Count of {col}")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### 2.13 `Occupation`

# %%
col= "occupation"
plt.figure(figsize=(6, 4))
sns.countplot(x=col, data=data)
plt.title(f"Count of {col}")
plt.xticks(rotation=85)
plt.show()

# %%
# Date conversions
data['account_open_date'] = pd.to_datetime(data['account_open_date'])
data['earliest_credit_account'] = pd.to_datetime(data['earliest_credit_account'])
data['recent_trade_activity'] = pd.to_datetime(data['recent_trade_activity'])

# %% [markdown]
# ### 2.14 `Account_open_date`

# %%
col = "account_open_date"
plt.figure(figsize=(6, 4))
sns.histplot(data[col], kde=True, color='blue', bins=30)
plt.title(f"Distribution of {col}")
plt.xlabel(f'{col}')
plt.ylabel('Frequency')
plt.show()
# Out:
# C:\Users\hcham\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ### 2.15 `Earliest_credit_account`

# %%
col = "earliest_credit_account"
plt.figure(figsize=(6, 4))
sns.histplot(data[col], kde=True, color='blue', bins=30)
plt.title(f"Distribution of {col}")
plt.xlabel(f'{col}')
plt.ylabel('Frequency')
plt.show()
# Out:
# C:\Users\hcham\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ### 2.16 `Recent_trade_activity`

# %%
col = "recent_trade_activity"
plt.figure(figsize=(6, 4))
sns.histplot(data[col], kde=True, color='blue', bins=30)
plt.title(f"Distribution of {col}")
plt.xlabel(f'{col}')
plt.ylabel('Frequency')
plt.show()
# Out:
# C:\Users\hcham\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
