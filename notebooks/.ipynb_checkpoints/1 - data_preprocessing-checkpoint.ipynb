# %%
# !pip install xgboost

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import chi2_contingency
from xgboost import XGBRegressor,XGBClassifier
from sklearn.impute import KNNImputer
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,mean_absolute_error, mean_squared_error, r2_score
import numpy as np
import math

# %% [markdown]
# ## 1- Loading Data

# %%
path = "../data/fraud_detection_dataset.csv"
data = pd.read_csv(path)

# %% [markdown]
# ## 2- Inspecting Data

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7000 entries, 0 to 6999
# Data columns (total 23 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   account_open_date                        7000 non-null   object
#  1   age                                      7000 non-null   int64
#  2   location                                 7000 non-null   object
#  3   occupation                               7000 non-null   object
#  4   income_level                             7000 non-null   int64
#  5   fico_score                               6790 non-null   float64
#  6   delinquency_status                       7000 non-null   int64
#  7   charge_off_status                        7000 non-null   bool
#  8   number_of_credit_applications            7000 non-null   int64
#  9   debt_to_income_ratio                     7000 non-null   float64
#  10  payment_methods_high_risk                7000 non-null   bool
#  11  max_balance                              7000 non-null   float64
#  12  avg_balance_last_12months                6650 non-null   float64
#  13  number_of_delinquent_accounts            6300 non-null   float64
#  14  number_of_defaulted_accounts             7000 non-null   int64
#  15  earliest_credit_account                  7000 non-null   object
#  16  recent_trade_activity                    7000 non-null   object
#  17  new_accounts_opened_last_12months        7000 non-null   int64
#  18  multiple_applications_short_time_period  7000 non-null   bool
#  19  unusual_submission_pattern               6090 non-null   object
#  20  applications_submitted_during_odd_hours  7000 non-null   bool
#  21  watchlist_blacklist_flag                 7000 non-null   bool
#  22  public_records_flag                      7000 non-null   bool
# dtypes: bool(6), float64(5), int64(6), object(6)
# memory usage: 970.8+ KB

# %%
data.head()
# Out:
#   account_open_date  age     location occupation  income_level  fico_score  \
# 0         11/9/2023   56  Los Angeles    Teacher         40099       424.0
# 1         9/11/2022   69     New York   Engineer          2050       483.0
# 2         7/12/2020   46        Miami   Engineer         71936       566.0
# 3         8/13/2024   32      Houston     Banker         15833         NaN
# 4         7/27/2024   60      Houston     Lawyer          8574       787.0
#
#    delinquency_status  charge_off_status  number_of_credit_applications  \
# 0                 108               True                             10
# 1                   0              False                              1
# 2                   0              False                              1
# 3                  97               True                              5
# 4                   0              False                              1
#
#    debt_to_income_ratio  ...  number_of_delinquent_accounts  \
# 0              3.139572  ...                            4.0
# 1              1.017489  ...                            3.0
# 2              1.508626  ...                            2.0
# 3              2.995150  ...                            3.0
# 4              1.182380  ...                            NaN
#
#    number_of_defaulted_accounts  earliest_credit_account  \
# 0                             2                9/11/2018
# 1                             2                 3/8/2023
# 2                             0                4/26/2024
# 3                             1                9/14/2023
# 4                             0                11/8/2022
#
#    recent_trade_activity  new_accounts_opened_last_12months  \
# 0               3/7/2024                                  3
# 1              1/28/2024                                  3
# 2              10/3/2024                                  2
# 3             10/14/2024                                  4
# 4               9/2/2024                                  0
#
#   multiple_applications_short_time_period unusual_submission_pattern  \
# 0                                    True                       True
# 1                                   False                       True
# 2                                   False                      False
# 3                                   False                       True
# 4                                    True                      False
#
#    applications_submitted_during_odd_hours  watchlist_blacklist_flag  \
# 0                                    False                     False
# 1                                    False                     False
# 2                                    False                     False
# 3                                     True                     False
# 4                                     True                     False
#
#   public_records_flag
# 0                True
# 1               False
# 2               False
# 3               False
# 4               False
#
# [5 rows x 23 columns]

# %%
data.describe()
# Out:
#                age  income_level   fico_score  delinquency_status  \
# count  7000.000000   7000.000000  6790.000000         7000.000000
# mean     46.208857  23739.063714   616.424448           25.226714
# std      16.401828  21846.844041   132.567079           42.709195
# min      18.000000   2000.000000   152.000000            0.000000
# 25%      32.000000   6927.250000   520.000000            0.000000
# 50%      46.000000  15014.000000   636.000000            0.000000
# 75%      61.000000  38299.750000   723.000000           29.000000
# max      74.000000  99957.000000   943.000000          119.000000
#
#        number_of_credit_applications  debt_to_income_ratio    max_balance  \
# count                    7000.000000           7000.000000    7000.000000
# mean                        1.813000              1.477630   50337.829377
# std                         1.934719              0.687469   49507.198629
# min                         1.000000              0.438413     930.516529
# 25%                         1.000000              1.052709   25496.283316
# 50%                         1.000000              1.320565   44679.410787
# 75%                         1.000000              1.720369   70157.462957
# max                        10.000000              9.975930  999922.083300
#
#        avg_balance_last_12months  number_of_delinquent_accounts  \
# count                6650.000000                    6300.000000
# mean                33638.208194                       1.212857
# std                 22358.889181                       1.558081
# min                   457.869809                       0.000000
# 25%                 13699.263133                       0.000000
# 50%                 30352.353060                       0.000000
# 75%                 52039.232172                       3.000000
# max                 92117.793445                       4.000000
#
#        number_of_defaulted_accounts  new_accounts_opened_last_12months
# count                   7000.000000                        7000.000000
# mean                       0.499143                           1.382429
# std                        0.729435                           1.594714
# min                        0.000000                           0.000000
# 25%                        0.000000                           0.000000
# 50%                        0.000000                           0.000000
# 75%                        1.000000                           3.000000
# max                        2.000000                           4.000000

# %% [markdown]
# ## 4- Converting Data Types

# %%
# Date conversions
data['account_open_date'] = pd.to_datetime(data['account_open_date'])
data['earliest_credit_account'] = pd.to_datetime(data['earliest_credit_account'])
data['recent_trade_activity'] = pd.to_datetime(data['recent_trade_activity'])

# %%
# Categorical conversions
data['location'] = data['location'].astype('category')
data['occupation'] = data['occupation'].astype('category')

# %%
# Boolean to 0,1 convention 
data['multiple_applications_short_time_period'] = data['multiple_applications_short_time_period'].astype(int)
data['watchlist_blacklist_flag'] = data['watchlist_blacklist_flag'].astype(int)
data['public_records_flag'] = data['public_records_flag'].astype(int)
data['applications_submitted_during_odd_hours'] = data['applications_submitted_during_odd_hours'].astype(int)
data['payment_methods_high_risk'] = data['payment_methods_high_risk'].astype(int)
data['charge_off_status'] = data['charge_off_status'].astype(int)

# %% [markdown]
# ## 3- Handling Missing Values

# %%
# Summary of missing values in each column
missing_summary = data.isnull().sum()
missing_summary = missing_summary[missing_summary > 0].sort_values(ascending=False)
print(missing_summary)
# Out:
# unusual_submission_pattern       910
# number_of_delinquent_accounts    700
# avg_balance_last_12months        350
# fico_score                       210
# dtype: int64

# %% [markdown]
# ### 3.1 - `avg_balance_last_12months`

# %%
mean_value = data['avg_balance_last_12months'].mean()
median_value = data['avg_balance_last_12months'].median()
std_dev = data['avg_balance_last_12months'].std()
skewness = data['avg_balance_last_12months'].skew()
kurtosis = data['avg_balance_last_12months'].kurt()

print(f"Mean: {mean_value}")
print(f"Median: {median_value}")
print(f"Standard Deviation: {std_dev}")
print(f"Skewness: {skewness}")
print(f"Kurtosis: {kurtosis}")

plt.figure(figsize=(10, 6))
sns.histplot(data['avg_balance_last_12months'], kde=True, bins=30)
plt.axvline(mean_value, color='r', linestyle='--', label=f'Mean: {mean_value:.2f}')
plt.axvline(median_value, color='g', linestyle='-', label=f'Median: {median_value:.2f}')
plt.title('Distribution of avg_balance_last_12months')
plt.xlabel('avg_balance_last_12months')
plt.ylabel('Frequency')
plt.legend()
plt.show()
# Out:
# Mean: 33638.20819360806
# Median: 30352.353060193185
# Standard Deviation: 22358.889181084403
# Skewness: 0.40219292066235507
# Kurtosis: -0.9413789598163418
# C:\Users\hcham\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# - Since the distributoin is slightly skewed but not excessively, missing values in `avg_balance_last_12months` features were decided to impute with the median value

# %%
data['avg_balance_last_12months'].fillna(data['avg_balance_last_12months'].median(), inplace=True)
# Out:
# C:\Users\hcham\AppData\Local\Temp\ipykernel_3748\452116180.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['avg_balance_last_12months'].fillna(data['avg_balance_last_12months'].median(), inplace=True)

# %%
# Summary of missing values in each column
missing_summary = data.isnull().sum()
missing_summary = missing_summary[missing_summary > 0].sort_values(ascending=False)
print(missing_summary)
# Out:
# unusual_submission_pattern       910
# number_of_delinquent_accounts    700
# fico_score                       210
# dtype: int64

# %% [markdown]
# ### 3.2 - `fico_score`

# %% [markdown]
# #### 3.2.1 - Missing Values

# %%
mean_value = data['fico_score'].mean()
median_value = data['fico_score'].median()
std_dev = data['fico_score'].std()
skewness = data['fico_score'].skew()
kurtosis = data['fico_score'].kurt()

print(f"Mean: {mean_value}")
print(f"Median: {median_value}")
print(f"Standard Deviation: {std_dev}")
print(f"Skewness: {skewness}")
print(f"Kurtosis: {kurtosis}")

plt.figure(figsize=(10, 6))
sns.histplot(data['fico_score'], kde=True, bins=30)
plt.axvline(mean_value, color='r', linestyle='--', label=f'Mean: {mean_value:.2f}')
plt.axvline(median_value, color='g', linestyle='-', label=f'Median: {median_value:.2f}')
plt.title('Distribution of fico_score')
plt.xlabel('fico_score')
plt.ylabel('Frequency')
plt.legend()
plt.show()
# Out:
# Mean: 616.4244477172313
# Median: 636.0
# Standard Deviation: 132.5670790673516
# Skewness: -0.4046865981149867
# Kurtosis: -0.641137989365796
# C:\Users\hcham\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Filter the rows where fico_score is missing
missing_fico_data = data[data['fico_score'].isna()]

# Check the distribution of 'earliest_credit_account' and 'account_open_date' for missing fico_score
missing_fico_data[['earliest_credit_account', 'account_open_date']].describe()
# Out:
#              earliest_credit_account    account_open_date
# count                            210                  210
# mean   2019-11-26 11:05:08.571428608  2022-03-30 04:00:00
# min              2014-10-29 00:00:00  2019-10-27 00:00:00
# 25%              2017-07-28 12:00:00  2020-12-03 12:00:00
# 50%              2020-02-15 12:00:00  2022-01-13 12:00:00
# 75%              2022-02-19 18:00:00  2023-09-08 12:00:00
# max              2024-10-12 00:00:00  2024-10-23 00:00:00

# %%
plt.figure(figsize=(14, 6))

# Plotting account_open_date distribution
plt.subplot(1, 2, 1)
sns.histplot(missing_fico_data['account_open_date'], kde=True, color='blue', bins=30)
plt.title('Distribution of Account Open Date for Missing FICO Score')
plt.xlabel('Account Open Date')
plt.ylabel('Frequency')

# Plotting earliest_credit_account distribution
plt.subplot(1, 2, 2)
sns.histplot(missing_fico_data['earliest_credit_account'], kde=True, color='green', bins=30)
plt.title('Distribution of Earliest Credit Account for Missing FICO Score')
plt.xlabel('Earliest Credit Account Date')
plt.ylabel('Frequency')

plt.show()
# Out:
# C:\Users\hcham\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\hcham\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# - The missing values in the `fico_score` variable do not show any clear pattern related to account dates or ages, suggesting that they are likely due to data entry errors. Since the number of missing values is small and does not seem to follow a specific trend, these rows have been removed to ensure the dataset remains accurate and reliable for analysis.

# %%
# Drop rows where 'fico_score' is missing
data_after_dropped_by_fico_score = data.dropna(subset=['fico_score'])

# %%
# Summary of missing values in each column
missing_summary = data_after_dropped_by_fico_score.isnull().sum()
missing_summary = missing_summary[missing_summary > 0].sort_values(ascending=False)
print(missing_summary)
# Out:
# unusual_submission_pattern       889
# number_of_delinquent_accounts    678
# dtype: int64

# %% [markdown]
# #### 3.2.1 - Out of range values
#
# - It was observed that there are values out of the range 300 - 850.

# %%
invalid_fico = data_after_dropped_by_fico_score[(data_after_dropped_by_fico_score['fico_score'] < 300) | (data_after_dropped_by_fico_score['fico_score'] > 850)]
print(f"Number of invalid FICO scores: {len(invalid_fico)}")
invalid_fico.head()
# Out:
# Number of invalid FICO scores: 42
#     account_open_date  age location          occupation  income_level  \
# 131        2022-02-26   24    Miami  Software Developer          9972
# 161        2024-08-11   26  Houston               Other          6959
# 862        2024-02-19   46    Miami              Banker          3202
# 908        2021-03-25   48  Seattle          Accountant         39792
# 920        2024-05-03   34   Boston               Other          7897
#
#      fico_score  delinquency_status  charge_off_status  \
# 131       920.0                  98                  1
# 161       923.0                 104                  1
# 862       938.0                   0                  0
# 908       278.0                   0                  0
# 920       906.0                   0                  0
#
#      number_of_credit_applications  debt_to_income_ratio  ...  \
# 131                              6              1.472118  ...
# 161                              2              1.753587  ...
# 862                              2              1.842488  ...
# 908                              1              2.266673  ...
# 920                              1              0.982923  ...
#
#      number_of_delinquent_accounts  number_of_defaulted_accounts  \
# 131                            NaN                             2
# 161                            3.0                             1
# 862                            0.0                             0
# 908                            0.0                             0
# 920                            0.0                             0
#
#      earliest_credit_account  recent_trade_activity  \
# 131               2020-10-05             2024-01-28
# 161               2023-12-28             2024-02-08
# 862               2024-01-12             2024-06-05
# 908               2020-03-27             2023-11-12
# 920               2021-05-19             2024-04-17
#
#      new_accounts_opened_last_12months  \
# 131                                  3
# 161                                  3
# 862                                  0
# 908                                  0
# 920                                  0
#
#     multiple_applications_short_time_period unusual_submission_pattern  \
# 131                                       1                       True
# 161                                       1                       True
# 862                                       0                        NaN
# 908                                       0                      False
# 920                                       0                      False
#
#      applications_submitted_during_odd_hours  watchlist_blacklist_flag  \
# 131                                        1                         0
# 161                                        0                         0
# 862                                        0                         0
# 908                                        0                         0
# 920                                        0                         0
#
#     public_records_flag
# 131                   0
# 161                   0
# 862                   0
# 908                   0
# 920                   1
#
# [5 rows x 23 columns]

# %%
# Remove rows where 'fico_score' is less than 300 or greater than 850
data_after_dropped_by_fico_score = data_after_dropped_by_fico_score[(data_after_dropped_by_fico_score['fico_score'] >= 300) & (data_after_dropped_by_fico_score['fico_score'] <= 850)]

# %%
# Summary of missing values in each column
missing_summary = data_after_dropped_by_fico_score.isnull().sum()
missing_summary = missing_summary[missing_summary > 0].sort_values(ascending=False)
print(missing_summary)
# Out:
# unusual_submission_pattern       882
# number_of_delinquent_accounts    674
# dtype: int64

# %% [markdown]
# To handle missing values of `unusual_submission_pattern` and `number_of_delinquent_accounts` we are going to use imputations methods.However to prevent **data leakage**  **(Train-Test Contamination)** , we split the data set in to train and test and trained the imputation model using trainig data only

# %%
train_data, test_data = train_test_split(data_after_dropped_by_fico_score, test_size=0.2, random_state=1)

# %% [markdown]
# ### 3.3 - `unusual_submission_pattern`
# - `unusual_submission_pattern` has 882 missing values. This is about 13% of the data. So if we remove those that would affect the dataset a lot. So we choose to impute this with some value by analyzing its relationship with other variables

# %%
# 1. Visualizing categorical variables against 'unusual_submission_pattern'

# Convert 'unusual_submission_pattern' to a string
data_after_dropped_by_fico_score['unusual_submission_pattern_str'] = data_after_dropped_by_fico_score['unusual_submission_pattern'].astype(str)

features = ['multiple_applications_short_time_period', 'watchlist_blacklist_flag', 'public_records_flag','applications_submitted_during_odd_hours','payment_methods_high_risk']

for feature in features:
    plt.figure(figsize=(5, 3))
    sns.countplot(data=data_after_dropped_by_fico_score, x=feature, hue='unusual_submission_pattern_str')
    plt.title(f'Relationship between {feature} and unusual_submission_pattern')
    plt.show()

# %%
# 2. Chi-Square Test for realted features 
for feature in features:
    contingency_table = pd.crosstab(data_after_dropped_by_fico_score[feature], data_after_dropped_by_fico_score['unusual_submission_pattern_str'])
    chi2, p_value, dof, expected = chi2_contingency(contingency_table)
    print(f"Chi-square test for {feature}:\n p-value: {p_value}")

# %%
# 3. Correlation Analysis for realted features 
features = ['multiple_applications_short_time_period', 'watchlist_blacklist_flag', 'public_records_flag','applications_submitted_during_odd_hours','payment_methods_high_risk']
target = 'unusual_submission_pattern'
# Check for any missing values in the target and features
data_for_testing = data_after_dropped_by_fico_score.dropna(subset=[target] + features)

# Ensure the target and features are of numeric type
data_for_testing[features] = data_for_testing[features].astype(int)
data_for_testing[target] = data_for_testing[target].astype(int)

# Calculate Pearson correlation for each binary feature with the target
correlations = {}
for feature in features:
    corr = data_for_testing[feature].corr(data_for_testing[target])  # Pearson correlation between feature and target
    correlations[feature] = corr

# Sort the correlations in descending order
sorted_correlations = sorted(correlations.items(), key=lambda x: abs(x[1]), reverse=True)

# Display the top features based on correlation with the target
top_features = [x[0] for x in sorted_correlations[:3]]  # You can adjust the number of features as needed
print(f"Top Features Based on Pearson Correlation: {top_features}")

# %% [markdown]
# - According to the above analysis due to features `multiple_applications_short_time_period`, `applications_submitted_during_odd_hours`, and `payment_methods_high_risk`, indicated a significant chi-square test results and correlations,There for a Weighted KNN imputation was chosen for handling missing values in the `unusual_submission_pattern` feature due to its ability to capture complex relationships. Weighted KNN was choosed due to inbalance of values

# %%
# Define features and target
features = ['multiple_applications_short_time_period', 
            'applications_submitted_during_odd_hours', 
            'payment_methods_high_risk']
target = 'unusual_submission_pattern'

# Map the target column to numeric
train_data[target] = train_data[target].map({True: 1, False: 0})
test_data[target] = test_data[target].map({True: 1, False: 0})

# Split train_data into rows with and without missing values
non_missing_train = train_data[train_data[target].notna()]
missing_train = train_data[train_data[target].isna()]

# Train the XGBoost model on non-missing training data
X_train = non_missing_train[features]
y_train = non_missing_train[target]

class_weight_ratio = (len(y_train) - sum(y_train)) / sum(y_train)

xgb_model = XGBClassifier(scale_pos_weight=class_weight_ratio,n_estimators=100, learning_rate=0.1, max_depth=5, random_state=1)
xgb_model.fit(X_train, y_train)

# Predict missing values in the training set
X_missing_train = missing_train[features]
predicted_train = xgb_model.predict(X_missing_train)

# Replace missing values in train_data
train_data.loc[train_data[target].isna(), target] = predicted_train

# Apply the same imputation model to the test_data
missing_test = test_data[test_data[target].isna()]
X_missing_test = missing_test[features]
predicted_test = xgb_model.predict(X_missing_test)

# Replace missing values in test_data
test_data.loc[test_data[target].isna(), target] = predicted_test

# Convert the imputed column back to boolean for consistency
train_data[target] = train_data[target].map({1: True, 0: False})
test_data[target] = test_data[target].map({1: True, 0: False})

print("Imputation completed without data leakage.")
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[51], line 19
#      16 X_train = non_missing_train[features]
#      17 y_train = non_missing_train[target]
# ---> 19 class_weight_ratio = (len(y_train) - sum(y_train)) / sum(y_train)
#      21 xgb_model = XGBClassifier(scale_pos_weight=class_weight_ratio,n_estimators=100, learning_rate=0.1, max_depth=5, random_state=1)
#      22 xgb_model.fit(X_train, y_train)
#
# ZeroDivisionError: division by zero

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report

# Filter test data to include only rows where the target is not missing
known_test_data = test_data[test_data[target].notna()]

# Features and actual target values
X_test_eval = known_test_data[features]
y_test_actual = known_test_data[target]

# Predict using the trained XGBoost model
y_test_pred = xgb_model.predict(X_test_eval)

# Calculate evaluation metrics
accuracy = accuracy_score(y_test_actual, y_test_pred)
precision = precision_score(y_test_actual, y_test_pred)
recall = recall_score(y_test_actual, y_test_pred)
f1 = f1_score(y_test_actual, y_test_pred)

# Print metrics
print(f"Accuracy: {accuracy:.2f}")
print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"F1 Score: {f1:.2f}")

# Confusion Matrix
conf_matrix = confusion_matrix(y_test_actual, y_test_pred)
print("Confusion Matrix:")
print(conf_matrix)

# Detailed Classification Report
print("Classification Report:")
print(classification_report(y_test_actual, y_test_pred))

# Optionally visualize the confusion matrix
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="coolwarm", xticklabels=["False", "True"], yticklabels=["False", "True"])
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()
# Out:
# Accuracy: 1.00
# Precision: 0.00
# Recall: 0.00
# F1 Score: 0.00
# Confusion Matrix:
# [[1350]]
# Classification Report:
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00      1350
#
#     accuracy                           1.00      1350
#    macro avg       1.00      1.00      1.00      1350
# weighted avg       1.00      1.00      1.00      1350
# C:\Users\hcham\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\hcham\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\hcham\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1757: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))

# %% [markdown]
# ### 3.1.1 Using Weighted KNN to impute missing values for `unusual_submission_pattern`

# %%
# Define the features and target
features = ['multiple_applications_short_time_period', 
            'applications_submitted_during_odd_hours', 
            'payment_methods_high_risk']
target = 'unusual_submission_pattern'

# Convert 'unusual_submission_pattern' to numerical (1 for True, 0 for False, NaN remains NaN)
data[target] = data[target].map({True: 1, False: 0})

# Select the rows where 'unusual_submission_pattern' is not NaN for fitting the imputer
data_for_imputation = data[features + [target]]

# Initialize the KNN Imputer with k=5 
knn_imputer = KNNImputer(n_neighbors=5,weights='distance')

# Apply the KNN imputation
data_imputed = knn_imputer.fit_transform(data_for_imputation)

# Convert the imputed numpy array back to a DataFrame
data_imputed_df = pd.DataFrame(data_imputed, columns=features + [target]).round().astype(int)

# Replace the original 'unusual_submission_pattern' column with the imputed values
data['unusual_submission_pattern'] = data_imputed_df[target]

# %%
# Summary of missing values in each column
missing_summary = data.isnull().sum()
missing_summary = missing_summary[missing_summary > 0].sort_values(ascending=False)
print(missing_summary)

# %% [markdown]
# ### 3.4 - `number_of_delinquent_accounts`

# %%
data_after_dropped_by_fico_score['number_of_delinquent_accounts_filled'] = data_after_dropped_by_fico_score['number_of_delinquent_accounts'].fillna('Missing')

plt.figure(figsize=(6, 4))
sns.countplot(x='number_of_delinquent_accounts_filled', data=data_after_dropped_by_fico_score)
plt.title('Distribution of number_of_delinquent_accounts with Missing Values')
plt.xlabel('Number of Delinquent Accounts')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(6, 4))
sns.countplot(x='number_of_defaulted_accounts', data=data_after_dropped_by_fico_score)
plt.title('Distribution of number_of_defaulted_accounts with Missing Values')
plt.xlabel('Number_of_defaulted_accounts')
plt.ylabel('Count')
plt.show()

# %%
# Checking the distribution of 'number_of_delinquent_accounts' with 'number_of_defaulted_accounts'
plt.figure(figsize=(8, 4))
sns.boxplot(x='number_of_defaulted_accounts', y='number_of_delinquent_accounts', data=data_after_dropped_by_fico_score)
plt.title('Relationship between Number of Delinquent Accounts and Number of Defaulted Accounts')
plt.xlabel('Number of Defaulted Accounts')
plt.ylabel('Number of Delinquent Accounts')
plt.show()

# %%
# Check the distribution of 'number_of_delinquent_accounts' with 'delinquency_status'
plt.figure(figsize=(8, 4))
sns.scatterplot(x='delinquency_status', y='number_of_delinquent_accounts', data=data_after_dropped_by_fico_score)
plt.title('Relationship between Number of Delinquent Accounts and Delinquency Status (Days Late)')
plt.xlabel('Delinquency Status (Days Late)')
plt.ylabel('Number of Delinquent Accounts')
plt.show()

# %%
# Calculate the correlation matrix
correlation_matrix = data_after_dropped_by_fico_score[['number_of_delinquent_accounts', 'number_of_defaulted_accounts', 'delinquency_status']].corr()

# Create a mask for the upper triangle
mask = np.triu(np.ones_like(correlation_matrix, dtype=bool))

# Set up the matplotlib figure
plt.figure(figsize=(4, 3))

# Draw the heatmap with the mask
sns.heatmap(correlation_matrix, mask=mask, annot=True, cmap='coolwarm', vmin=-1, vmax=1, square=True, cbar_kws={"shrink": .8})
plt.title("Correlation Matrix")
plt.show()
# Out:
# C:\Users\hcham\anaconda3\Lib\site-packages\seaborn\matrix.py:260: FutureWarning: Format strings passed to MaskedConstant are ignored, but in future may error or produce different behavior
#   annotation = ("{:" + self.fmt + "}").format(val)

# %%
plt.figure(figsize=(5, 4))
scatter = plt.scatter(
    data_after_dropped_by_fico_score['delinquency_status'],
    data_after_dropped_by_fico_score['number_of_defaulted_accounts'],
    c=data_after_dropped_by_fico_score['number_of_delinquent_accounts'],
    cmap='viridis', 
    s=20,  
    alpha=0.7  
)
plt.colorbar(scatter, label='Number of Delinquent Accounts')
plt.title('Relationship among Delinquency Status, Defaulted Accounts, and Delinquent Accounts')
plt.xlabel('Delinquency Status (Days Late)')
plt.ylabel('Number of Defaulted Accounts')
plt.show()

# %% [markdown]
# ### 3.4.1 Traning XGBRegressor to impute missing values for `number_of_delinquent_accounts`

# %%
# Split data into rows with and without missing 'number_of_delinquent_accounts'
data_complete_train = train_data[train_data['number_of_delinquent_accounts'].notna()]
data_complete_test = test_data[test_data['number_of_delinquent_accounts'].notna()]
data_missing_train = train_data[train_data['number_of_delinquent_accounts'].isna()]
data_missing_test = test_data[test_data['number_of_delinquent_accounts'].isna()]

# Define predictor and target variables
X = data_complete_train[['number_of_defaulted_accounts', 'delinquency_status']]
y = data_complete_train['number_of_delinquent_accounts']

# Split complete data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# Define the regression model
xgb_regressor = XGBRegressor(eval_metric='rmse')

# Train the model
xgb_regressor.fit(X_train, y_train)

# Predict
y_pred = xgb_regressor.predict(X_test)

# Evaluate the model
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = math.sqrt(mse) 
r2 = r2_score(y_test, y_pred)

print(f"Mean Absolute Error: {mae:.2f}")
print(f"Mean Squared Error: {mse:.2f}")
print(f"Root Mean Squared Error: {rmse:.2f}")
print(f"R-squared: {r2:.2f}")
# Out:
# Mean Absolute Error: 0.43
# Mean Squared Error: 0.40
# Root Mean Squared Error: 0.63
# R-squared: 0.84

# %% [markdown]
# The model performs well for imputing missing `number_of_delinquent_accounts` values, with an **R-squared** of 0.84, indicating it explains 87% of the variance. The low **Mean Absolute Error (0.43)** and **Mean Squared Error (0.40)** show that the predictions are accurate, and the **Root Mean Squared Error (0.63)** suggests minimal prediction errors. These results demonstrate the model's strong predictive ability, making it a reliable tool for imputing missing values in your dataset.

# %% [markdown]
# ### 3.4.2 Imputing missing values for `number_of_delinquent_accounts` using XGBRegressor

# %%
# Prepare missing data for prediction
X_missing_train = data_missing_train[['number_of_defaulted_accounts', 'delinquency_status']]
X_missing_test = data_missing_test[['number_of_defaulted_accounts', 'delinquency_status']]

# Predict the missing values
data_missing_train.loc[:, 'number_of_delinquent_accounts'] = xgb_regressor.predict(X_missing_train).round()
data_missing_test.loc[:, 'number_of_delinquent_accounts'] = xgb_regressor.predict(X_missing_test).round()

# Clip values to ensure they are within the valid range (0 to 4)
data_missing_train.loc[:, 'number_of_delinquent_accounts'] = data_missing_train['number_of_delinquent_accounts'].clip(0, 4)
data_missing_test.loc[:, 'number_of_delinquent_accounts'] = data_missing_test['number_of_delinquent_accounts'].clip(0, 4)

# Combine the data back
data_imputed_train = pd.concat([data_complete_train, data_missing_train])
data_imputed_test = pd.concat([data_complete_test, data_missing_test])

# %%
# Full Dataset
full_imputed_dataset = pd.concat([data_imputed_train, data_imputed_test])

# %%
# Summary of missing values in each column
missing_summary = full_imputed_dataset.isnull().sum()
missing_summary = missing_summary[missing_summary > 0].sort_values(ascending=False)
print(missing_summary)
# Out:
# unusual_submission_pattern    882
# dtype: int64

# %%
full_data_pre_prpocessed = full_imputed_dataset.drop(columns=["unusual_submission_pattern_str"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 full_data_pre_prpocessed = full_imputed_dataset.drop(columns=["unusual_submission_pattern_str"])
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:4788, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786 for axis, labels in axes.items():
#    4787     if labels is not None:
# -> 4788         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4790 if inplace:
#    4791     self._update_inplace(obj)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:4830, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4828         new_axis = axis.drop(labels, level=level, errors=errors)
#    4829     else:
# -> 4830         new_axis = axis.drop(labels, errors=errors)
#    4831     indexer = axis.get_indexer(new_axis)
#    4833 # Case for non-unique axis
#    4834 else:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:7070, in Index.drop(self, labels, errors)
#    7068 if mask.any():
#    7069     if errors != "ignore":
# -> 7070         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071     indexer = indexer[~mask]
#    7072 return self.delete(indexer)
#
# KeyError: "['unusual_submission_pattern_str'] not found in axis"

# %%
full_data_pre_prpocessed.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 full_data_pre_prpocessed.info()
#
# NameError: name 'full_data_pre_prpocessed' is not defined

# %%
full_data_pre_prpocessed.describe()

# %% [markdown]
# ## 4. Saving the final Worksheet

# %%
data_pre_prpocessed.to_csv("../data/pre_prpocessed_dataset.csv")
